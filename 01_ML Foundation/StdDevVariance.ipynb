# %% [markdown]
# #### Standard Daviation and Variance

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.normal(100,20,1000)
data
# Out:
# array([128.42721679, 111.95212489, 110.46598457, 135.1245641 ,
#        101.04816241, 106.58855902, 126.90593733, 133.88660436,
#        133.26656182,  99.98040192,  84.02845863,  87.23975841,
#         90.51021047, 110.23540157,  98.68837272,  41.04963345,
#         94.60787965,  98.80751864,  88.30072604, 114.21896603,
#        115.3498206 ,  87.77429601, 136.28607437, 103.50790198,
#         94.44047178, 131.58284227,  85.73706861, 124.25568336,
#        181.39352767, 100.34898272, 120.67514924, 101.24987089,
#         54.60955573,  89.637093  ,  76.16298806,  87.50303594,
#         72.0845349 , 106.37428296, 106.50058787, 102.6593642 ,
#        110.27426902,  67.68048922,  83.85815554, 118.26231644,
#        124.61003714, 101.16189753, 101.68132048,  83.77599949,
#         85.48492071,  69.97276335, 132.92386787,  84.09166021,
#         86.98812045,  90.48059735,  87.46679664, 101.36963158,
#         88.77787176,  58.31757663,  61.10044877, 106.55700259,
# ...

# %%
plt.hist(data,50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.std()
# Out:
# 20.195000692746728

# %%
data.var()
# Out:
# 407.8380529800408

# %%
np.mean(data)
# Out:
# 99.83576900857138
