# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.random.normal(50,2,10000)

# %%
plt.hist(data,100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.percentile(data,10)
# Out:
# 47.45637622193955
