# %% [markdown]
# #### Standard Daviation and Variance

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.normal(100,20,1000)
data
# Out:
# array([ 76.28485461, 118.23966843,  90.52580398, 105.47411653,
#         61.55867168,  55.45705416, 109.05770791, 103.36417345,
#         95.06248967, 101.55973525, 106.81273518,  80.49271309,
#         65.29071571, 114.79799916, 128.32920976, 107.99145355,
#        114.33874702, 107.71794665, 115.46453126, 126.07756347,
#         79.68956354,  74.21125403, 116.36749881,  80.09051486,
#         81.98060882,  99.48477286,  80.44624633, 100.81893758,
#        112.53364511,  86.64825272, 103.01566933, 104.58760143,
#        100.63846069,  75.90199602, 104.99663176, 108.1538145 ,
#        108.55297141, 106.3284408 ,  79.42767492, 110.99262256,
#        109.92243633,  69.87220985,  84.43886308, 123.19812817,
#        135.54208648,  78.51647114,  89.19355069, 128.55950497,
#        110.40520558, 100.47708351, 100.39695619,  69.26367637,
#         56.0520986 ,  88.34554787,  70.48414724,  95.45181854,
#         64.29666851,  98.71251109, 100.08817621,  94.68868512,
# ...

# %%
plt.hist(data,50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.std()
# Out:
# 19.72536738227631

# %%
data.var()
# Out:
# 389.0901183657702

# %%
hii=0
